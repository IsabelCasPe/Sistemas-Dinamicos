# %% [markdown]
# # Equaçoes
# dx/dt=σ(y-x)
# dy/dt=x(𝜌-z)-y
# dz/dt=xy-𝛽z
#
# onde:
#
# σ é o parâmetro de Prandtl (geralmente 𝜎=10),
#
# ρ é o número de Rayleigh (um valor comum é ρ=28),
#
# β é uma constante que geralmente é 8/3.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.integrate import solve_ivp
from matplotlib.animation import FuncAnimation

# %%
# Parâmetros do sistema de Lorenz
sigma = 10.0
rho = 28.0
beta = 8.0 / 3.0

# %%
# Função que define o sistema de Lorenz
def lorenz(t, state):
    x, y, z = state
    dx_dt = sigma * (y - x)
    dy_dt = x * (rho - z) - y
    dz_dt = x * y - beta * z
    return [dx_dt, dy_dt, dz_dt]

# %%
# Condições iniciais
initial_state = [0.0, 1.0, 1.05]

# Tempo de integração
t_span = (0, 40)
t_eval = np.linspace(t_span[0], t_span[1], 10000)

# Solução numérica do sistema
solution = solve_ivp(lorenz, t_span, initial_state, t_eval=t_eval)

# Extração das trajetórias
x, y, z = solution.y

# %%
# Visualização do sistema de Lorenz em 3D
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
ax.plot(x, y, z, lw=0.5, color='b')
ax.set_title("Atração Caótica do Sistema de Lorenz")
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")
plt.show()

# %% [markdown]
# # Interpretação do Sistema de Lorenz
# O sistema de Lorenz foi criado inicialmente para modelar padrões atmosféricos e acabou se tornando um clássico dos sistemas dinâmicos por demonstrar **caos determinístico**. Ele exibe um comportamento extremamente sensível às condições iniciais, conhecido como o **efeito borboleta**, onde pequenas mudanças no início resultam em grandes diferenças na trajetória ao longo do tempo.
#
# # Principais Características
# 1. **Atrator Caótico**:
#    - O gráfico 3D mostra uma estrutura chamada **atrator de Lorenz**, onde a trajetória parece "flutuar" em torno de duas regiões principais, sem se estabilizar em uma órbita fixa. Essa estrutura é chamada de **atrator estranho**.
#    - A trajetória nunca se cruza, mas continua oscilando de forma irregular em torno de duas regiões.
#
# 2. **Sensibilidade às Condições Iniciais**:
#    - Pequenas variações nas condições iniciais resultariam em trajetórias completamente diferentes ao longo do tempo, mesmo que o sistema siga as mesmas equações. Esse fenômeno mostra o caos no sistema de Lorenz.
#
# 3. **Transição entre "Lóbulos"**:
#    - No gráfico, você pode ver que o sistema oscila entre duas "asas" ou "lóbulos", como se estivesse alternando entre duas regiões principais. Cada "volta" pode durar mais ou menos tempo, mas o sistema nunca repete exatamente o mesmo caminho.
#
# 4. **Comportamento Não-Periódico**:
#    - Mesmo após um longo tempo, a trajetória não se repete nem forma um padrão estável, o que é característico de um sistema caótico.
#
# # Conclusão
# Esse atrator mostra a beleza e complexidade dos sistemas caóticos, onde a dinâmica nunca se estabiliza, mas mantém uma estrutura subjacente que gera padrões ricos e imprevisíveis. O sistema de Lorenz, por isso, é usado em pesquisas sobre clima, mercado financeiro, e até em redes de comunicação, onde entender o caos é essencial.
